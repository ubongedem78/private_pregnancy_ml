# %% [markdown]
# ### Imports

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Load the dataset and understand the dataset

# %%
# Load the dataset
file_path = '../input/maternal-health-risk-data/Maternal Health Risk Data Set.csv'
data = pd.read_csv(file_path)

# %%
# Display the first few rows to understand the data
print(data.head())
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.0      98.0         86  high risk
# 1   35         140           90  13.0      98.0         70  high risk
# 2   29          90           70   8.0     100.0         80  high risk
# 3   30         140           85   7.0      98.0         70  high risk
# 4   35         120           60   6.1      98.0         76   low risk

# %%
# Separate features and target variable
X = data.drop(columns=['RiskLevel'])
y = data['RiskLevel']

# %%
df=data.copy()

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
df.shape
# Out:
# (452, 7)

# %%
df.replace({"high risk":2, "mid risk":1, "low risk":0}, inplace=True)
df.head()
# Out:
# /tmp/ipykernel_30/247815498.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({"high risk":2, "mid risk":1, "low risk":0}, inplace=True)
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.0      98.0         86          2
# 1   35         140           90  13.0      98.0         70          2
# 2   29          90           70   8.0     100.0         80          2
# 3   30         140           85   7.0      98.0         70          2
# 4   35         120           60   6.1      98.0         76          0

# %%
fig, axes = plt.subplots(nrows=1,ncols=2, figsize=(14,6))

sns.countplot(ax=axes[0], x=df.RiskLevel)
axes[0].set_title("Count of observations by Risk Level")

sns.boxplot(ax=axes[1], x=df.RiskLevel, y=df.Age)
axes[1].set_title("Age by Risk Level")
# Out:
# Text(0.5, 1.0, 'Age by Risk Level')

# %%
sns.boxplot(x=df.RiskLevel, y=df.BS).set_title("Blood Glucose by Risk Level")
# Out:
# Text(0.5, 1.0, 'Blood Glucose by Risk Level')

# %%
fig, axes = plt.subplots(nrows=1,ncols=2, figsize=(14,6))

sns.histplot(ax=axes[0], x=df.DiastolicBP)
axes[0].set_title("Distribution of Lower value of Blood Pressure, mmHg")

sns.histplot(ax=axes[1], x=df.SystolicBP, color="#ed894e")
axes[1].set_title("Distribution of Upper value of Blood Pressure, mmHg")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Distribution of Upper value of Blood Pressure, mmHg')

# %%
fig, axes = plt.subplots(nrows=1,ncols=2, figsize=(14,6))

sns.boxplot(ax=axes[0], x=df.RiskLevel, y=df.DiastolicBP)
axes[0].set_title("Lower value of Blood Pressure by Risk Level")

sns.boxplot(ax=axes[1], x=df.RiskLevel, y=df.SystolicBP)
axes[1].set_title("Upper value of Blood Pressure by Risk Level")
# Out:
# Text(0.5, 1.0, 'Upper value of Blood Pressure by Risk Level')

# %%
fig, axes = plt.subplots(nrows=1,ncols=2, figsize=(14,6))

sns.scatterplot(x=df.DiastolicBP, y=df.Age, ax=axes[0])
axes[0].set_title("Lower value of Blood Pressure VS Age")

sns.scatterplot(ax=axes[1], x=df.SystolicBP, y=df.Age, color="#ed894e")
axes[1].set_title("Upper value of Blood Pressure VS Age")
# Out:
# Text(0.5, 1.0, 'Upper value of Blood Pressure VS Age')

# %%
sns.violinplot(y=df.BodyTemp, x=df.RiskLevel).set_title("Body Temperature by Risk Level")
# Out:
# Text(0.5, 1.0, 'Body Temperature by Risk Level')

# %%
df.HeartRate.mode()
# Out:
# 0    70
# Name: HeartRate, dtype: int64

# %%
df.loc[df.HeartRate == 7, "HeartRate"] = 70

# %%
fig, axes = plt.subplots(nrows=1,ncols=2, figsize=(14,6))

sns.histplot(ax=axes[0], x=df.HeartRate)
axes[0].set_title("Distribution of Heart Rate")

sns.boxplot(ax=axes[1], x=df.RiskLevel, y=df.HeartRate)
axes[1].set_title("Heart Rate by Risk Level")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Heart Rate by Risk Level')

# %% [markdown]
# ### Observations from visualizations above:
# - The **low risk pregnancies** are the most frequent overall, they happen in more than half of the cases.
# - Younger women tend to have **low** and **mid** risk pregnancies, while the pregnancies of women above 35 y.o. more often are classified as **high** risk, thus, need more attention.
# - If a pregnant woman has a **blood sugar** higher than 8 mmol/L, in most of the cases, the pregnancy is considered high risk.
# - Distribution of lower value of **blood pressure** is more spread, around 60-100 mmHg, compared to distribution of upper value, which is centered around 120 mmHg.
# - Higher **blood pressure** (both systolic and diastolic), higher **body temperature** are associated with **higher risk** pregnancies.
# - As for correlation between age and blood pressure, very low blood pressure (both systolic and diastolic) was observed in some of the girls and young women, but normal and high blood pressure don't seem to be much correlated with age, at least in our dataset.
# - Heart rate of pregnant women is **normally distributed** and it's only slightly associated with risk level.

# %% [markdown]
# ### Encode the target variable and split the dataset

# %%
# Encode the target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)  # Converts 'RiskLevel' to numeric values
y_categorical = to_categorical(y_encoded)    # Converts numeric labels to one-hot encoding

# %%
# Split the data into training, validation, and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y_categorical, test_size=0.2, random_state=42)

# %%
# Standardize the features (important for neural networks)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Define a more complex model with dropout layers to avoid overfitting
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dropout(0.5))  # Dropout layer to prevent overfitting
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))  # Another dropout layer
model.add(Dense(32, activation='relu'))
model.add(Dense(3, activation='softmax'))  # 3 output classes (high, medium, low risk)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### Compile and train the model for 100 epochs

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Implement early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.3484 - loss: 1.0999 - val_accuracy: 0.5153 - val_loss: 0.9992
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5252 - loss: 0.9907 - val_accuracy: 0.6012 - val_loss: 0.9144
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5662 - loss: 0.9295 - val_accuracy: 0.6074 - val_loss: 0.8586
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5666 - loss: 0.9018 - val_accuracy: 0.6074 - val_loss: 0.8224
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6069 - loss: 0.8357 - val_accuracy: 0.6012 - val_loss: 0.8017
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6331 - loss: 0.8024 - val_accuracy: 0.6135 - val_loss: 0.7819
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6360 - loss: 0.7862 - val_accuracy: 0.6442 - val_loss: 0.7716
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6184 - loss: 0.7985 - val_accuracy: 0.6687 - val_loss: 0.7538
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6425 - loss: 0.7928 - val_accuracy: 0.6626 - val_loss: 0.7474
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6613 - loss: 0.7572 - val_accuracy: 0.6503 - val_loss: 0.7371
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6168 - loss: 0.7932 - val_accuracy: 0.6626 - val_loss: 0.7298
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6674 - loss: 0.7546 - val_accuracy: 0.6626 - val_loss: 0.7321
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6581 - loss: 0.7646 - val_accuracy: 0.6626 - val_loss: 0.7205
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6477 - loss: 0.7560 - val_accuracy: 0.6748 - val_loss: 0.7126
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6761 - loss: 0.7388 - val_accuracy: 0.6564 - val_loss: 0.7030
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6344 - loss: 0.7481 - val_accuracy: 0.6564 - val_loss: 0.7101
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6735 - loss: 0.7113 - val_accuracy: 0.6442 - val_loss: 0.7055
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7018 - loss: 0.6733 - val_accuracy: 0.6687 - val_loss: 0.6993
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6843 - loss: 0.7162 - val_accuracy: 0.6687 - val_loss: 0.6952
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6914 - loss: 0.7116 - val_accuracy: 0.6442 - val_loss: 0.6912
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7029 - loss: 0.6737 - val_accuracy: 0.6503 - val_loss: 0.6871
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6837 - loss: 0.7019 - val_accuracy: 0.6442 - val_loss: 0.6817
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6891 - loss: 0.6685 - val_accuracy: 0.6564 - val_loss: 0.6849
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6860 - loss: 0.6941 - val_accuracy: 0.6380 - val_loss: 0.6776
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6786 - loss: 0.6979 - val_accuracy: 0.6319 - val_loss: 0.6719
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6892 - loss: 0.6724 - val_accuracy: 0.6380 - val_loss: 0.6755
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6986 - loss: 0.6732 - val_accuracy: 0.6380 - val_loss: 0.6737
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6982 - loss: 0.6643 - val_accuracy: 0.6319 - val_loss: 0.6721
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7008 - loss: 0.6553 - val_accuracy: 0.6503 - val_loss: 0.6621
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6899 - loss: 0.6623 - val_accuracy: 0.6626 - val_loss: 0.6660
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6982 - loss: 0.6900 - val_accuracy: 0.6503 - val_loss: 0.6574
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7264 - loss: 0.6293 - val_accuracy: 0.6564 - val_loss: 0.6570
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7015 - loss: 0.6917 - val_accuracy: 0.6442 - val_loss: 0.6577
# Epoch 34/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6814 - loss: 0.6689 - val_accuracy: 0.6503 - val_loss: 0.6529
# Epoch 35/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7132 - loss: 0.6666 - val_accuracy: 0.6687 - val_loss: 0.6503
# Epoch 36/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7210 - loss: 0.6531 - val_accuracy: 0.6626 - val_loss: 0.6456
# Epoch 37/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7138 - loss: 0.6480 - val_accuracy: 0.6503 - val_loss: 0.6469
# Epoch 38/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6825 - loss: 0.6653 - val_accuracy: 0.6626 - val_loss: 0.6473
# Epoch 39/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6889 - loss: 0.6403 - val_accuracy: 0.6258 - val_loss: 0.6417
# Epoch 40/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7010 - loss: 0.6688 - val_accuracy: 0.6319 - val_loss: 0.6352
# Epoch 41/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7108 - loss: 0.6422 - val_accuracy: 0.6503 - val_loss: 0.6362
# Epoch 42/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7086 - loss: 0.6544 - val_accuracy: 0.6319 - val_loss: 0.6350
# Epoch 43/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7097 - loss: 0.6482 - val_accuracy: 0.6380 - val_loss: 0.6393
# Epoch 44/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6966 - loss: 0.6724 - val_accuracy: 0.6503 - val_loss: 0.6381
# Epoch 45/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7067 - loss: 0.6548 - val_accuracy: 0.6380 - val_loss: 0.6334
# Epoch 46/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6891 - loss: 0.6688 - val_accuracy: 0.6258 - val_loss: 0.6290
# Epoch 47/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7473 - loss: 0.6192 - val_accuracy: 0.6442 - val_loss: 0.6381
# Epoch 48/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7193 - loss: 0.6017 - val_accuracy: 0.6503 - val_loss: 0.6314
# Epoch 49/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7376 - loss: 0.6282 - val_accuracy: 0.6503 - val_loss: 0.6353
# Epoch 50/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6974 - loss: 0.6650 - val_accuracy: 0.6442 - val_loss: 0.6314
# Epoch 51/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7089 - loss: 0.6122 - val_accuracy: 0.6442 - val_loss: 0.6287
# Epoch 52/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6990 - loss: 0.6564 - val_accuracy: 0.6503 - val_loss: 0.6288
# Epoch 53/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7168 - loss: 0.6576 - val_accuracy: 0.6319 - val_loss: 0.6273
# Epoch 54/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7149 - loss: 0.6205 - val_accuracy: 0.6503 - val_loss: 0.6261
# Epoch 55/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7096 - loss: 0.6327 - val_accuracy: 0.6687 - val_loss: 0.6255
# Epoch 56/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6985 - loss: 0.6570 - val_accuracy: 0.6564 - val_loss: 0.6248
# Epoch 57/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7309 - loss: 0.6140 - val_accuracy: 0.6564 - val_loss: 0.6217
# Epoch 58/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6985 - loss: 0.6308 - val_accuracy: 0.6626 - val_loss: 0.6206
# Epoch 59/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7197 - loss: 0.6281 - val_accuracy: 0.6687 - val_loss: 0.6207
# Epoch 60/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7183 - loss: 0.5917 - val_accuracy: 0.6687 - val_loss: 0.6227
# Epoch 61/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7048 - loss: 0.6184 - val_accuracy: 0.6626 - val_loss: 0.6173
# Epoch 62/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7065 - loss: 0.6089 - val_accuracy: 0.6626 - val_loss: 0.6136
# Epoch 63/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7205 - loss: 0.6275 - val_accuracy: 0.6810 - val_loss: 0.6170
# Epoch 64/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7257 - loss: 0.6150 - val_accuracy: 0.6564 - val_loss: 0.6163
# Epoch 65/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7317 - loss: 0.6234 - val_accuracy: 0.6564 - val_loss: 0.6151
# Epoch 66/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6988 - loss: 0.6514 - val_accuracy: 0.6687 - val_loss: 0.6159
# Epoch 67/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7241 - loss: 0.6053 - val_accuracy: 0.6503 - val_loss: 0.6197
# Epoch 68/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6945 - loss: 0.6259 - val_accuracy: 0.6442 - val_loss: 0.6145
# Epoch 69/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7034 - loss: 0.6605 - val_accuracy: 0.6503 - val_loss: 0.6152
# Epoch 70/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6793 - loss: 0.6456 - val_accuracy: 0.6380 - val_loss: 0.6167
# Epoch 71/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7216 - loss: 0.6110 - val_accuracy: 0.6503 - val_loss: 0.6203
# Epoch 72/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7255 - loss: 0.5843 - val_accuracy: 0.6503 - val_loss: 0.6136

# %% [markdown]
# ### Evaluvate the model

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy:.2f}")
# Generate predictions and decode them
y_pred = model.predict(X_test)
y_pred_labels = y_pred.argmax(axis=1)
y_true_labels = y_test.argmax(axis=1)
# Out:
# Test Accuracy: 0.67
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
# Classification report
print(classification_report(y_true_labels, y_pred_labels, target_names=label_encoder.classes_))
# Out:
#               precision    recall  f1-score   support
#
#    high risk       0.77      0.87      0.82        47
#     low risk       0.61      0.86      0.71        80
#     mid risk       0.75      0.36      0.48        76
#
#     accuracy                           0.67       203
#    macro avg       0.71      0.70      0.67       203
# weighted avg       0.70      0.67      0.65       203

# %% [markdown]
# ### Display the normalized confusion matrix

# %%
# Confusion matrix
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)

# Normalize by row (true class) - each row sums to 1
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Plotting the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_normalized, annot=True, fmt=".2f", cmap="Blues", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Normalized Confusion Matrix")
plt.show()
